# %%
# %pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
img_path = "./dataset/archive/images/1.jpg"

# %%
import cv2 as cv

# %%
img = cv.imread(img_path)

# %%
img.shape # 3 boyutlu bir array -> tensor
# Out:
# (4608, 2592, 3)

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt") # model yükle
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:01<00:00, 4.44MB/s]

# %%
model.train(data="data.yaml", epochs=1, imgsz=640, batch=8) # modeli eğit
# Out:
# Ultralytics 8.3.138 🚀 Python-3.9.21 torch-2.7.0 CPU (Apple M3 Pro)
# ...
